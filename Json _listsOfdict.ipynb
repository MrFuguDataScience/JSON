# %% [markdown]
# # `Parse List of Lists of Dictionaries:` Solving 1 problem multiple ways! 🤠
#
# # <font color=red size =6>Mr Fugu Data Science</font>
#
# # (◕‿◕✿)
#
# # Purpose & Outcome;
#
# + Start small: parse 1 example (multiple ways)
# + Then, work out parsing and iterating lists of dictionaries
# + Finally, move onto parsing json object with values that are lists of dictionaries

# %%
import json 
import pandas as pd
from collections import defaultdict
from collections import ChainMap

# %%
# NY Times API Raw Data:
df_to_parse=pd.read_json('nytimes_api.json')
df_to_parse['media']
# Out:
# 0     [{'type': 'image', 'subtype': 'photo', 'captio...
# 1     [{'type': 'image', 'subtype': 'photo', 'captio...
# 2     [{'type': 'image', 'subtype': 'photo', 'captio...
# 3     [{'type': 'image', 'subtype': 'photo', 'captio...
# 4     [{'type': 'image', 'subtype': 'photo', 'captio...
# 5     [{'type': 'image', 'subtype': 'photo', 'captio...
# 6     [{'type': 'image', 'subtype': 'photo', 'captio...
# 7                                                    []
# 8     [{'type': 'image', 'subtype': 'photo', 'captio...
# 9     [{'type': 'image', 'subtype': 'photo', 'captio...
# 10    [{'type': 'image', 'subtype': 'photo', 'captio...
# 11    [{'type': 'image', 'subtype': 'photo', 'captio...
# 12    [{'type': 'image', 'subtype': 'photo', 'captio...
# 13                                                   []
# 14    [{'type': 'image', 'subtype': 'photo', 'captio...
# 15                                                   []
# 16    [{'type': 'image', 'subtype': 'photo', 'captio...
# 17    [{'type': 'image', 'subtype': 'photo', 'captio...
# 18    [{'type': 'image', 'subtype': 'photo', 'captio...
# 19    [{'type': 'image', 'subtype': 'photo', 'captio...
# Name: media, dtype: object

# %% [markdown]
# # list of dictionaries: Single Entry

# %%
df_to_parse['media'][0] # single entry to parse first as practice
# Out:
# [{'type': 'image',
#   'subtype': 'photo',
#   'caption': 'Michael Reinoehl was killed by a federally led fugitive task force in Lacey, Wash., on Thursday. He was being investigated in a fatal shooting at a Portland protest.',
#   'copyright': 'Joshua Bessex for The New York Times',
#   'approved_for_syndication': 1,
#   'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75},
#    {'url': 'https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210},
#    {'url': 'https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440}]}]

# %% [markdown]
# # Inside `df_to_parse['media'] `there is another list of dictionaries, which is one of the values (*further nesting*)
#
#
# `'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75},
#    {'url': 'https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210},
#    {'url': 'https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440}]}]`
#
# `----------------------------------`
#
# **We will work backwards and get an idea how to deal with this**
#
# + To Clarify: this is 1 entry of `media-metadata`, so pay attention. Each *url* should be a list of *url's* for each entry.
#     + Thus, further formatting is needed.

# %%
media_meta={'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-thumbStandard.jpg',
    'format': 'Standard Thumbnail',
    'height': 75,
    'width': 75},
   {'url': 'https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-mediumThreeByTwo210.jpg',
    'format': 'mediumThreeByTwo210',
    'height': 140,
    'width': 210},
   {'url': 'https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-mediumThreeByTwo440.jpg',
    'format': 'mediumThreeByTwo440',
    'height': 293,
    'width': 440}]}
    
    
pd.DataFrame(media_meta['media-metadata'])
# Out:
#                                                  url               format  \
# 0  https://static01.nyt.com/images/2020/10/03/us/...   Standard Thumbnail
# 1  https://static01.nyt.com/images/2020/10/03/us/...  mediumThreeByTwo210
# 2  https://static01.nyt.com/images/2020/10/03/us/...  mediumThreeByTwo440
#
#    height  width
# 0      75     75
# 1     140    210
# 2     293    440

# %% [markdown]
# # This is in theory how each of the *url's* should appear *`when done parsing and formatting`*
#
# + `Notice:` that the above cell had a list of *url's* but each url was a separate dictionary.
# + In this cell they have been converted to proper form for what I am trying to do here

# %%
two_entries=[{'url': ['https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-thumbStandard.jpg',
              'https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-mediumThreeByTwo210.jpg',
              'https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-mediumThreeByTwo440.jpg']},
{'url': ['https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-thumbStandard.jpg',
              'https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-mediumThreeByTwo210.jpg',
              'https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-mediumThreeByTwo440.jpg']}]
pd.DataFrame(two_entries)
# Out:
#                                                  url
# 0  [https://static01.nyt.com/images/2020/10/03/us...
# 1  [https://static01.nyt.com/images/2020/10/03/us...

# %% [markdown]
# # `Example 01`:  Use `Collections ChainMap`
#
# + This allows us to: essentially group multiple dictionaries to a single dictionary, with many options such as updates for example. Please, look at documentation for further explanation.
#
# https://docs.python.org/3/library/collections.html

# %%
multiDct_to_single=[]
for i in range(len(df_to_parse['media'])):
    qq=dict(ChainMap(*df_to_parse['media'][i][::-1])) # notice the star!
    multiDct_to_single.append(qq)


pd.DataFrame(multiDct_to_single).head()
# Out:
#     type subtype                                            caption  \
# 0  image   photo  Michael Reinoehl was killed by a federally led...
# 1  image   photo  The actor Chadwick Boseman in 2018. He was 35 ...
# 2  image   photo  I can’t get in to edit the digital column, Sho...
# 3  image   photo  Tests authorized by the F.D.A. provide only a ...
# 4  image   photo  Claudia Perez, left, and Carmen Quiñones appea...
#
#                               copyright  approved_for_syndication  \
# 0  Joshua Bessex for The New York Times                       1.0
# 1   Axel Koester for The New York Times                       1.0
# 2   Mason Trinca for The New York Times                       1.0
# 3  Johnny Milano for The New York Times                       1.0
# 4        Republican National Convention                       1.0
#
#                                       media-metadata
# 0  [{'url': 'https://static01.nyt.com/images/2020...
# 1  [{'url': 'https://static01.nyt.com/images/2020...
# 2  [{'url': 'https://static01.nyt.com/images/2020...
# 3  [{'url': 'https://static01.nyt.com/images/2020...
# 4  [{'url': 'https://static01.nyt.com/images/2020...

# %% [markdown]
# # `Example 02`: List comprehension, followed by iteratation

# %%
def merge_(*dicts):
    for i in dicts:
        return dict(*[d.items() for d in i])

# %%
func_w_iter=[]
for i in range(len(df_to_parse['media'])):
    a=merge_(df_to_parse['media'][i])
    func_w_iter.append(a)

pd.DataFrame(func_w_iter).head()
# Out:
#     type subtype                                            caption  \
# 0  image   photo  Michael Reinoehl was killed by a federally led...
# 1  image   photo  The actor Chadwick Boseman in 2018. He was 35 ...
# 2  image   photo  I can’t get in to edit the digital column, Sho...
# 3  image   photo  Tests authorized by the F.D.A. provide only a ...
# 4  image   photo  Claudia Perez, left, and Carmen Quiñones appea...
#
#                               copyright  approved_for_syndication  \
# 0  Joshua Bessex for The New York Times                       1.0
# 1   Axel Koester for The New York Times                       1.0
# 2   Mason Trinca for The New York Times                       1.0
# 3  Johnny Milano for The New York Times                       1.0
# 4        Republican National Convention                       1.0
#
#                                       media-metadata
# 0  [{'url': 'https://static01.nyt.com/images/2020...
# 1  [{'url': 'https://static01.nyt.com/images/2020...
# 2  [{'url': 'https://static01.nyt.com/images/2020...
# 3  [{'url': 'https://static01.nyt.com/images/2020...
# 4  [{'url': 'https://static01.nyt.com/images/2020...

# %% [markdown]
# # Example 03: `Parse List of Lists of Dictionaries`
#
# <font size=6>`Souppa Crazy Version: Wowzas`</font>
#
# #  <font size=9>🤯</font>
#
# + Don't get scared, it won't bite. Let's walk through it ok.

# %%
h=defaultdict(list)
d=[]
for i in range(len(df_to_parse['media'])):
    
    if len(df_to_parse['media'][i]) >0: # each list can be empty=0 or filled with len=1
        
        for j in df_to_parse['media'][i][0].items(): # convert dict->tup and iterate
            d.append([i,j]) # append (i=location,j=tuples)

    else: # w= my keys from above and create tuples with Nope as values
        
        w=tuple(zip(df_to_parse['media'][0][0].keys(),\
                  ['Sorry Nope']*len(df_to_parse['media'][0][0].keys())))
        for ii in w:
#             
            d.append([i,ii])

for jk in d:
    h[jk[1][0]].append(jk[1][1]) # list of lists again with tuples as second param

    
new_df=pd.DataFrame(h)
new_df
# Out:
#           type     subtype                                            caption  \
# 0        image       photo  Michael Reinoehl was killed by a federally led...
# 1        image       photo  The actor Chadwick Boseman in 2018. He was 35 ...
# 2        image       photo  I can’t get in to edit the digital column, Sho...
# 3        image       photo  Tests authorized by the F.D.A. provide only a ...
# 4        image       photo  Claudia Perez, left, and Carmen Quiñones appea...
# 5        image       photo  Protesters gathered at the site where Daniel P...
# 6        image       photo
# 7   Sorry Nope  Sorry Nope                                         Sorry Nope
# 8        image       photo  A queue for an open house in Belleville, a New...
# 9        image       photo  Curtis Flowers, center, as he exited the Winst...
# 10       image       photo  A volunteer received an experimental coronavir...
# 11       image       photo  A suspected Covid-19 patient arriving at the e...
# 12       image       photo  Estudiantes en un aula de la Universidad de Gi...
# 13  Sorry Nope  Sorry Nope                                         Sorry Nope
# 14       image       photo  Stephanie Winston Wolkoff writes: “Yes, Operat...
# 15  Sorry Nope  Sorry Nope                                         Sorry Nope
# 16       image       photo  “We just passed a guy in a jetpack,” an Americ...
# 17       image       photo  The next chapter in the saga of Prince Harry a...
# 18       image       photo  Chadwick Boseman at the Black Panther premiere...
# 19       image       photo  President Donald Trump delivers remarks on Imm...
#
#                                             copyright  \
# 0                Joshua Bessex for The New York Times
# 1                 Axel Koester for The New York Times
# 2                 Mason Trinca for The New York Times
# 3                Johnny Milano for The New York Times
# 4                      Republican National Convention
# 5      Joshua Rashaad McFadden for The New York Times
# 6                 Brendan Gutenschwager, via Storyful
# 7                                          Sorry Nope
# 8                Karsten Moran for The New York Times
# 9                   Rogelio V. Solis/Associated Press
# 10  Henry Ford Health System/Agence France-Presse ...
# 11               Samuel Aranda for The New York Times
# 12                  David Borrat/EPA vía Shutterstock
# 13                                         Sorry Nope
# 14  Nicholas Kamm/Agence France-Presse — Getty Images
# 15                                         Sorry Nope
# 16    Daniel Slim/Agence France-Presse — Getty Images
# 17  Daniel Leal-Olivas/Agence France-Presse — Gett...
# 18      Chris Pizzello/Invision, via Associated Press
# 19                      Doug Mills/The New York Times
#
#    approved_for_syndication                                     media-metadata
# 0                         1  [{'url': 'https://static01.nyt.com/images/2020...
# 1                         1  [{'url': 'https://static01.nyt.com/images/2020...
# 2                         1  [{'url': 'https://static01.nyt.com/images/2020...
# 3                         1  [{'url': 'https://static01.nyt.com/images/2020...
# 4                         1  [{'url': 'https://static01.nyt.com/images/2020...
# 5                         1  [{'url': 'https://static01.nyt.com/images/2020...
# 6                         0  [{'url': 'https://static01.nyt.com/images/2020...
# 7                Sorry Nope                                         Sorry Nope
# 8                         1  [{'url': 'https://static01.nyt.com/images/2020...
# 9                         1  [{'url': 'https://static01.nyt.com/images/2020...
# 10                        1  [{'url': 'https://static01.nyt.com/images/2020...
# 11                        1  [{'url': 'https://static01.nyt.com/images/2020...
# 12                        1  [{'url': 'https://static01.nyt.com/images/2020...
# 13               Sorry Nope                                         Sorry Nope
# 14                        1  [{'url': 'https://static01.nyt.com/images/2020...
# 15               Sorry Nope                                         Sorry Nope
# 16                        1  [{'url': 'https://static01.nyt.com/images/2020...
# 17                        1  [{'url': 'https://static01.nyt.com/images/2020...
# 18                        1  [{'url': 'https://static01.nyt.com/images/2020...
# 19                        1  [{'url': 'https://static01.nyt.com/images/2020...

# %% [markdown]
# # I created this to illustrate how I made the tuples based on the keys for our dictionary.
#
# + **`Side Note`**: if you have lists of dictionaries of varying lengths then you have to do 1 more step.
#     + You would have to basically find all unique keys such as using a `set` operator. Then you would need to do `if/else` statements to make sure that everything lined up.
#
# `This example didn't have this problem`

# %%
tuple(zip(df_to_parse['media'][0][0].keys(),\
                  ['Nope']*len(df_to_parse['media'][0][0].keys())))
# Out:
# (('type', 'Nope'),
#  ('subtype', 'Nope'),
#  ('caption', 'Nope'),
#  ('copyright', 'Nope'),
#  ('approved_for_syndication', 'Nope'),
#  ('media-metadata', 'Nope'))

# %% [markdown]
# # `Example 04`: Inner most list of lists of dictionaries `['media-metadata']`

# %%
def func(dict_):
    h=defaultdict(list)
    for j in dict_:
        if type(j)!=str:
            for i in j.items():
                h[i[0]].append(i[1])
    return h


t_=[]
g=defaultdict(list)
for i in range(len(new_df['media-metadata'])):
    
    if type(new_df['media-metadata'][i])!=str:
        t_.append(func(new_df['media-metadata'][i]))
    
    else:
        tups=tuple(zip(new_df['media-metadata'][0][0].keys() ,
                               ['Nope']*len(new_df['media-metadata'][0][0].keys())))
        for n in tups:
            g[n[0]].append(n[1])
        t_.append(g)
        

print(pd.DataFrame(t_).url[0])
print('--------------------')
print(pd.DataFrame(t_).url[1])

#
url_expand_=pd.DataFrame(t_)
url_expand_
# Out:
# ['https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-thumbStandard.jpg', 'https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-mediumThreeByTwo210.jpg', 'https://static01.nyt.com/images/2020/10/03/us/03portland-suspect-alt/03portland-suspect-alt-mediumThreeByTwo440.jpg']
# --------------------
# ['https://static01.nyt.com/images/2020/08/29/multimedia/29xp-boseman1/29xp-boseman1-thumbStandard.jpg', 'https://static01.nyt.com/images/2020/08/29/multimedia/29xp-boseman1/29xp-boseman1-mediumThreeByTwo210.jpg', 'https://static01.nyt.com/images/2020/08/29/multimedia/29xp-boseman1/29xp-boseman1-mediumThreeByTwo440.jpg']
#                                                   url  \
# 0   [https://static01.nyt.com/images/2020/10/03/us...
# 1   [https://static01.nyt.com/images/2020/08/29/mu...
# 2   [https://static01.nyt.com/images/2020/08/30/us...
# 3   [https://static01.nyt.com/images/2020/08/30/sc...
# 4   [https://static01.nyt.com/images/2020/08/28/ny...
# 5   [https://static01.nyt.com/images/2020/09/05/ny...
# 6   [https://static01.nyt.com/images/2020/08/28/vi...
# 7                                  [Nope, Nope, Nope]
# 8   [https://static01.nyt.com/images/2020/08/28/ny...
# 9   [https://static01.nyt.com/images/2020/09/04/us...
# 10  [https://static01.nyt.com/images/2020/09/02/sc...
# 11  [https://static01.nyt.com/images/2020/08/31/wo...
# 12  [https://static01.nyt.com/images/2020/08/27/mu...
# 13                                 [Nope, Nope, Nope]
# 14  [https://static01.nyt.com/images/2020/09/01/bo...
# 15                                 [Nope, Nope, Nope]
# 16  [https://static01.nyt.com/images/2020/09/01/mu...
# 17  [https://static01.nyt.com/images/2020/09/02/bu...
# 18  [https://static01.nyt.com/images/2020/08/29/sc...
# 19  [https://static01.nyt.com/images/2020/08/27/bu...
#
#                                                format              height  \
# 0   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 1   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 2   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 3   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 4   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 5   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 6   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 7                                  [Nope, Nope, Nope]  [Nope, Nope, Nope]
# 8   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 9   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 10  [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 11  [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 12  [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 13                                 [Nope, Nope, Nope]  [Nope, Nope, Nope]
# 14  [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 15                                 [Nope, Nope, Nope]  [Nope, Nope, Nope]
# 16  [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 17  [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 18  [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 19  [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
#
#                  width
# 0       [75, 210, 440]
# 1       [75, 210, 440]
# 2       [75, 210, 440]
# 3       [75, 210, 440]
# 4       [75, 210, 440]
# 5       [75, 210, 440]
# 6       [75, 210, 440]
# 7   [Nope, Nope, Nope]
# 8       [75, 210, 440]
# 9       [75, 210, 440]
# 10      [75, 210, 440]
# 11      [75, 210, 440]
# 12      [75, 210, 440]
# 13  [Nope, Nope, Nope]
# 14      [75, 210, 440]
# 15  [Nope, Nope, Nope]
# 16      [75, 210, 440]
# 17      [75, 210, 440]
# 18      [75, 210, 440]
# 19      [75, 210, 440]

# %% [markdown]
# # Combine All Data into 1 DF:

# %%
pd.concat([df_to_parse,new_df,url_expand_],axis=1)
# Out:
#                                                   uri  \
# 0   nyt://article/f0510da8-1ef8-5442-a909-8af53b7d...
# 1   nyt://article/607123ea-14ba-5f9c-ab43-7d8b6c7a...
# 2   nyt://article/6bff4972-07cc-5b20-bd16-39f9cf19...
# 3   nyt://article/0487a919-ec10-5bf5-8f65-449c7a78...
# 4   nyt://article/7e66f291-6167-5d78-b942-4937278f...
# 5   nyt://article/93323728-2566-5176-9909-d107ce96...
# 6   nyt://article/fa102828-c20a-5f7c-8685-de98792a...
# 7   nyt://article/b1dd8dce-004c-556c-8043-ae7f9216...
# 8   nyt://article/024a4b57-909b-538d-91f4-fd8522c9...
# 9   nyt://article/587ec74f-656f-5d4b-b850-87b83536...
# 10  nyt://article/db950bc1-a962-5103-85a4-ab74e259...
# 11  nyt://article/f0d0f300-7046-5f22-8f20-8de8e9ee...
# 12  nyt://article/18f8bc5e-842a-57d4-8a89-a3312282...
# 13  nyt://article/03c07760-edab-5fc4-b8ae-ee8ee504...
# 14  nyt://article/61a9d791-1819-5f9d-adb5-c7c8fc64...
# 15  nyt://article/4a661751-31d3-5fb6-9276-114b2c2b...
# 16  nyt://article/76bd4ce0-7696-570a-9bec-3d2f35ac...
# 17  nyt://article/448a48be-03e2-58be-aa92-656c060d...
# 18  nyt://article/fe6aed91-291b-5433-919c-78dc8e41...
# 19  nyt://article/b62f497f-a937-5754-a8eb-944e8340...
#
#                                                   url               id  \
# 0   https://www.nytimes.com/2020/09/03/us/michael-...  100000007321101
# 1   https://www.nytimes.com/2020/08/28/movies/chad...  100000007314593
# 2   https://www.nytimes.com/2020/08/30/us/portland...  100000007315198
# 3   https://www.nytimes.com/2020/08/29/health/coro...  100000007294406
# 4   https://www.nytimes.com/2020/08/28/nyregion/ny...  100000007313944
# 5   https://www.nytimes.com/2020/09/03/nyregion/da...  100000007323110
# 6   https://www.nytimes.com/2020/08/27/us/kyle-rit...  100000007309185
# 7   https://www.nytimes.com/2020/08/28/world/europ...  100000007312969
# 8   https://www.nytimes.com/2020/08/30/nyregion/ny...  100000007292267
# 9   https://www.nytimes.com/2020/09/04/us/after-6-...  100000007325874
# 10  https://www.nytimes.com/2020/09/02/health/covi...  100000007320029
# 11  https://www.nytimes.com/2020/08/31/world/europ...  100000007316226
# 12  https://www.nytimes.com/es/2020/08/27/espanol/...  100000007308885
# 13  https://www.nytimes.com/2020/09/02/world/europ...  100000007320697
# 14  https://www.nytimes.com/2020/08/28/books/revie...  100000007310710
# 15  https://www.nytimes.com/2020/08/28/opinion/cor...  100000007304144
# 16  https://www.nytimes.com/2020/09/01/us/american...  100000007319236
# 17  https://www.nytimes.com/2020/09/02/business/me...  100000007320678
# 18  https://www.nytimes.com/2020/08/29/health/colo...  100000007314962
# 19  https://www.nytimes.com/2020/08/27/technology/...  100000007309905
#
#            asset_id          source published_date              updated  \
# 0   100000007321101  New York Times     2020-09-03  2020-09-05 10:04:00
# 1   100000007314593  New York Times     2020-08-28  2020-08-31 10:07:14
# 2   100000007315198  New York Times     2020-08-30  2020-09-05 10:05:01
# 3   100000007294406  New York Times     2020-08-29  2020-09-01 21:09:22
# 4   100000007313944  New York Times     2020-08-28  2020-09-03 11:03:02
# 5   100000007323110  New York Times     2020-09-03  2020-09-04 19:21:30
# 6   100000007309185  New York Times     2020-08-27  2020-09-03 14:36:58
# 7   100000007312969  New York Times     2020-08-28  2020-08-29 12:40:00
# 8   100000007292267  New York Times     2020-08-30  2020-08-31 03:14:52
# 9   100000007325874  New York Times     2020-09-04  2020-09-05 00:33:44
# 10  100000007320029  New York Times     2020-09-02  2020-09-04 15:25:05
# 11  100000007316226  New York Times     2020-08-31  2020-09-02 09:22:15
# 12  100000007308885  New York Times     2020-08-27  2020-09-03 13:26:30
# 13  100000007320697  New York Times     2020-09-02  2020-09-03 10:59:44
# 14  100000007310710  New York Times     2020-08-28  2020-09-02 10:21:50
# 15  100000007304144  New York Times     2020-08-28  2020-08-31 01:32:36
# 16  100000007319236  New York Times     2020-09-01  2020-09-02 14:46:40
# 17  100000007320678  New York Times     2020-09-02  2020-09-03 11:32:07
# 18  100000007314962  New York Times     2020-08-29  2020-09-03 09:44:24
# 19  100000007309905  New York Times     2020-08-27  2020-08-28 19:12:29
#
#        section   subsection nytdsection  ...        type     subtype  \
# 0         U.S.                     u.s.  ...       image       photo
# 1       Movies                   movies  ...       image       photo
# 2         U.S.                     u.s.  ...       image       photo
# 3       Health                   health  ...       image       photo
# 4     New York                 new york  ...       image       photo
# 5     New York                 new york  ...       image       photo
# 6         U.S.                     u.s.  ...       image       photo
# 7        World       Europe       world  ...  Sorry Nope  Sorry Nope
# 8     New York                 new york  ...       image       photo
# 9         U.S.                     u.s.  ...       image       photo
# 10      Health                   health  ...       image       photo
# 11       World       Europe       world  ...       image       photo
# 12  en Español      Opinión  en español  ...       image       photo
# 13       World       Europe       world  ...  Sorry Nope  Sorry Nope
# 14       Books  Book Review       books  ...       image       photo
# 15     Opinion                  opinion  ...  Sorry Nope  Sorry Nope
# 16        U.S.                     u.s.  ...       image       photo
# 17    Business        Media    business  ...       image       photo
# 18      Health                   health  ...       image       photo
# 19  Technology               technology  ...       image       photo
#
#                                               caption  \
# 0   Michael Reinoehl was killed by a federally led...
# 1   The actor Chadwick Boseman in 2018. He was 35 ...
# 2   I can’t get in to edit the digital column, Sho...
# 3   Tests authorized by the F.D.A. provide only a ...
# 4   Claudia Perez, left, and Carmen Quiñones appea...
# 5   Protesters gathered at the site where Daniel P...
# 6
# 7                                          Sorry Nope
# 8   A queue for an open house in Belleville, a New...
# 9   Curtis Flowers, center, as he exited the Winst...
# 10  A volunteer received an experimental coronavir...
# 11  A suspected Covid-19 patient arriving at the e...
# 12  Estudiantes en un aula de la Universidad de Gi...
# 13                                         Sorry Nope
# 14  Stephanie Winston Wolkoff writes: “Yes, Operat...
# 15                                         Sorry Nope
# 16  “We just passed a guy in a jetpack,” an Americ...
# 17  The next chapter in the saga of Prince Harry a...
# 18  Chadwick Boseman at the Black Panther premiere...
# 19  President Donald Trump delivers remarks on Imm...
#
#                                             copyright  \
# 0                Joshua Bessex for The New York Times
# 1                 Axel Koester for The New York Times
# 2                 Mason Trinca for The New York Times
# 3                Johnny Milano for The New York Times
# 4                      Republican National Convention
# 5      Joshua Rashaad McFadden for The New York Times
# 6                 Brendan Gutenschwager, via Storyful
# 7                                          Sorry Nope
# 8                Karsten Moran for The New York Times
# 9                   Rogelio V. Solis/Associated Press
# 10  Henry Ford Health System/Agence France-Presse ...
# 11               Samuel Aranda for The New York Times
# 12                  David Borrat/EPA vía Shutterstock
# 13                                         Sorry Nope
# 14  Nicholas Kamm/Agence France-Presse — Getty Images
# 15                                         Sorry Nope
# 16    Daniel Slim/Agence France-Presse — Getty Images
# 17  Daniel Leal-Olivas/Agence France-Presse — Gett...
# 18      Chris Pizzello/Invision, via Associated Press
# 19                      Doug Mills/The New York Times
#
#    approved_for_syndication  \
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         1
# 5                         1
# 6                         0
# 7                Sorry Nope
# 8                         1
# 9                         1
# 10                        1
# 11                        1
# 12                        1
# 13               Sorry Nope
# 14                        1
# 15               Sorry Nope
# 16                        1
# 17                        1
# 18                        1
# 19                        1
#
#                                        media-metadata  \
# 0   [{'url': 'https://static01.nyt.com/images/2020...
# 1   [{'url': 'https://static01.nyt.com/images/2020...
# 2   [{'url': 'https://static01.nyt.com/images/2020...
# 3   [{'url': 'https://static01.nyt.com/images/2020...
# 4   [{'url': 'https://static01.nyt.com/images/2020...
# 5   [{'url': 'https://static01.nyt.com/images/2020...
# 6   [{'url': 'https://static01.nyt.com/images/2020...
# 7                                          Sorry Nope
# 8   [{'url': 'https://static01.nyt.com/images/2020...
# 9   [{'url': 'https://static01.nyt.com/images/2020...
# 10  [{'url': 'https://static01.nyt.com/images/2020...
# 11  [{'url': 'https://static01.nyt.com/images/2020...
# 12  [{'url': 'https://static01.nyt.com/images/2020...
# 13                                         Sorry Nope
# 14  [{'url': 'https://static01.nyt.com/images/2020...
# 15                                         Sorry Nope
# 16  [{'url': 'https://static01.nyt.com/images/2020...
# 17  [{'url': 'https://static01.nyt.com/images/2020...
# 18  [{'url': 'https://static01.nyt.com/images/2020...
# 19  [{'url': 'https://static01.nyt.com/images/2020...
#
#                                                   url  \
# 0   [https://static01.nyt.com/images/2020/10/03/us...
# 1   [https://static01.nyt.com/images/2020/08/29/mu...
# 2   [https://static01.nyt.com/images/2020/08/30/us...
# 3   [https://static01.nyt.com/images/2020/08/30/sc...
# 4   [https://static01.nyt.com/images/2020/08/28/ny...
# 5   [https://static01.nyt.com/images/2020/09/05/ny...
# 6   [https://static01.nyt.com/images/2020/08/28/vi...
# 7                                  [Nope, Nope, Nope]
# 8   [https://static01.nyt.com/images/2020/08/28/ny...
# 9   [https://static01.nyt.com/images/2020/09/04/us...
# 10  [https://static01.nyt.com/images/2020/09/02/sc...
# 11  [https://static01.nyt.com/images/2020/08/31/wo...
# 12  [https://static01.nyt.com/images/2020/08/27/mu...
# 13                                 [Nope, Nope, Nope]
# 14  [https://static01.nyt.com/images/2020/09/01/bo...
# 15                                 [Nope, Nope, Nope]
# 16  [https://static01.nyt.com/images/2020/09/01/mu...
# 17  [https://static01.nyt.com/images/2020/09/02/bu...
# 18  [https://static01.nyt.com/images/2020/08/29/sc...
# 19  [https://static01.nyt.com/images/2020/08/27/bu...
#
#                                                format              height  \
# 0   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 1   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 2   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 3   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 4   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 5   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 6   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 7                                  [Nope, Nope, Nope]  [Nope, Nope, Nope]
# 8   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 9   [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 10  [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 11  [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 12  [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 13                                 [Nope, Nope, Nope]  [Nope, Nope, Nope]
# 14  [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 15                                 [Nope, Nope, Nope]  [Nope, Nope, Nope]
# 16  [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 17  [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 18  [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
# 19  [Standard Thumbnail, mediumThreeByTwo210, medi...      [75, 140, 293]
#
#                  width
# 0       [75, 210, 440]
# 1       [75, 210, 440]
# 2       [75, 210, 440]
# 3       [75, 210, 440]
# 4       [75, 210, 440]
# 5       [75, 210, 440]
# 6       [75, 210, 440]
# 7   [Nope, Nope, Nope]
# 8       [75, 210, 440]
# 9       [75, 210, 440]
# 10      [75, 210, 440]
# 11      [75, 210, 440]
# 12      [75, 210, 440]
# 13  [Nope, Nope, Nope]
# 14      [75, 210, 440]
# 15  [Nope, Nope, Nope]
# 16      [75, 210, 440]
# 17      [75, 210, 440]
# 18      [75, 210, 440]
# 19      [75, 210, 440]
#
# [20 rows x 32 columns]

# %% [markdown]
# # Last Thoughts:
#
# There are always various ways to solve a problem based on skill level, experience and Time/Memory tradeoff.
#
# + If you want a speed up and have the ability try using list comprehensions vs loops.
# + There are times when index valus MATTER, like I did in this video. Therefore, preserving order matters, and you have to adjust your code.
# + Finally, you can write elegant code over time: but, doesn't always mean that it is the best way to solve or fastest way either.

# %% [markdown]
# # <font color=red>LIKE</font>, Share &
#
# # <font color=red>SUB</font>scribe

# %% [markdown]
# `--------------------------------`
#
# # Citations & Help:
#
# # <font size=8 > ◔̯◔</font>
#
# https://stackoverflow.com/questions/10756427/loop-through-all-nested-dictionary-values
#
# https://stackabuse.com/reading-and-writing-json-to-a-file-in-python/
#
# https://florimond.dev/blog/articles/2018/07/a-practical-usage-of-chainmap-in-python/
